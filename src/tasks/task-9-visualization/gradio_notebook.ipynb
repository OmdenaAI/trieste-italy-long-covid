# %%
import gradio as gr
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# ###  Hello World example

# %%
def greet(name):
    return "Hello " + name + "!!"

demo = gr.Interface(fn=myplot)
demo.launch(share=True)

# %% [markdown]
# ### Display wordcloud

# %%
demo = gr.Blocks()

with demo:
    text = 'Fun, fun, awesome, awesome, tubular, astounding, superb, great, amazing, amazing, amazing, amazing'
    # Create and generate a word cloud image:
    wordcloud = WordCloud().generate(text)

    # Display the generated image:
    fig, ax = plt.subplots()
    im = ax.imshow(wordcloud, interpolation='bilinear')
    ax.set_axis_off()   
    gr.Plot(fig)

demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7868/
# Running on public URL: https://46620.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://46620.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x286486d68e0>,
#  'http://127.0.0.1:7868/',
#  'https://46620.gradio.app')
